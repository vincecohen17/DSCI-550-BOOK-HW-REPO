# %% [markdown]
# ...

# %%
import matplotlib.pyplot as plt

price = [12000, 23000, 25000, 15000, 56000, 20000, 65000, 30000, 15000, 20000]
engine_size = [1000, 2000, 2500, 1500, 3500, 2100, 1000, 1600, 3500, 990]
family_car = [0, 1, 1, 0, 0, 1, 0, 1, 0, 0]

color_map = {0: 'red', 1: 'blue'}

plt.figure(figsize=(10, 6))
for i in range(len(price)):
    plt.plot(price[i], engine_size[i], 'o', color=color_map[family_car[i]], markersize=8)
    

plt.plot(27000, 2000, 'o', color='yellow', label='q.1.c.a') # True 1
plt.plot(5000, 3000, 'o', color='green', label='q.1.c.b') # True 0
plt.plot(76000, 4000, 'o', color='cyan', label='q.1.c.c') # True 1

plt.plot(24500, 2400, 'o', color='red', label='q.1.d') # True 0
plt.show()
